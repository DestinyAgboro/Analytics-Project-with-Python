# %%
# regression using data set
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
import pandas as pd

# %%
df = pd.read_csv('/content/Housing.csv')
df.head()
# Out:
#    rownames  price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0         1  42000     5850         3        1        2      yes      no
# 1         2  38500     4000         2        1        1      yes      no
# 2         3  49500     3060         3        1        1      yes      no
# 3         4  60500     6650         3        1        2      yes     yes
# 4         5  61000     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
df.isnull().sum()
# Out:
# rownames    0
# price       0
# lotsize     0
# bedrooms    0
# bathrms     0
# stories     0
# driveway    0
# recroom     0
# fullbase    0
# gashw       0
# airco       0
# garagepl    0
# prefarea    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  546 non-null    int64
#  1   price     546 non-null    int64
#  2   lotsize   546 non-null    int64
#  3   bedrooms  546 non-null    int64
#  4   bathrms   546 non-null    int64
#  5   stories   546 non-null    int64
#  6   driveway  546 non-null    object
#  7   recroom   546 non-null    object
#  8   fullbase  546 non-null    object
#  9   gashw     546 non-null    object
#  10  airco     546 non-null    object
#  11  garagepl  546 non-null    int64
#  12  prefarea  546 non-null    object
# dtypes: int64(7), object(6)
# memory usage: 55.6+ KB

# %%
df.describe()
# Out:
#          rownames          price       lotsize    bedrooms     bathrms  \
# count  546.000000     546.000000    546.000000  546.000000  546.000000
# mean   273.500000   68121.597070   5150.265568    2.965201    1.285714
# std    157.760895   26702.670926   2168.158725    0.737388    0.502158
# min      1.000000   25000.000000   1650.000000    1.000000    1.000000
# 25%    137.250000   49125.000000   3600.000000    2.000000    1.000000
# 50%    273.500000   62000.000000   4600.000000    3.000000    1.000000
# 75%    409.750000   82000.000000   6360.000000    3.000000    2.000000
# max    546.000000  190000.000000  16200.000000    6.000000    4.000000
#
#           stories    garagepl
# count  546.000000  546.000000
# mean     1.807692    0.692308
# std      0.868203    0.861307
# min      1.000000    0.000000
# 25%      1.000000    0.000000
# 50%      2.000000    0.000000
# 75%      2.000000    1.000000
# max      4.000000    3.000000

# %%
df.shape
# Out:
# (546, 13)

# %%
X = df['lotsize']

# %%
y = df['price']

# %%
X=X.values.reshape(len(X),1)
Y=y.values.reshape(len(y),1)

# Split the data into training/testing sets
X_train = X[:-250]
X_test = X[-250:]

# Split the targets into training/testing sets
Y_train = Y[:-250]
Y_test = Y[-250:]

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((296, 1), (250, 1), (296, 1), (250, 1))

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, Y_train)

# Make predictions using the testing set
Y_pred = regr.predict(X_test)

# %%
# import the module
from sklearn.metrics import mean_absolute_error as mae

# %%
# calculate MAE
error = mae(Y_test, Y_pred)

# display
print("Mean absolute error : " + str(error))
# Out:
# Mean absolute error : 19657.844966318262

# %%
from sklearn.metrics import mean_squared_error

# %%
# Calculation of Mean Squared Error (MSE)
mse = mean_squared_error(Y_test,Y_pred)

# %%
from sklearn.metrics import mean_squared_error
import math

rmse = math.sqrt(mse)

# %%
rmse
# Out:
# 26943.451233890763

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['rownames', 'price', 'lotsize', 'bedrooms', 'bathrms', 'stories',
#        'driveway', 'recroom', 'fullbase', 'gashw', 'airco', 'garagepl',
#        'prefarea'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  546 non-null    int64
#  1   price     546 non-null    int64
#  2   lotsize   546 non-null    int64
#  3   bedrooms  546 non-null    int64
#  4   bathrms   546 non-null    int64
#  5   stories   546 non-null    int64
#  6   driveway  546 non-null    object
#  7   recroom   546 non-null    object
#  8   fullbase  546 non-null    object
#  9   gashw     546 non-null    object
#  10  airco     546 non-null    object
#  11  garagepl  546 non-null    int64
#  12  prefarea  546 non-null    object
# dtypes: int64(7), object(6)
# memory usage: 55.6+ KB

# %%
label_encoder = LabelEncoder()
df['driveway'] = label_encoder.fit_transform(df['driveway'])
df['recroom'] = label_encoder.fit_transform(df['recroom'])
df['fullbase'] = label_encoder.fit_transform(df['fullbase'])
df['gashw'] = label_encoder.fit_transform(df['gashw'])
df['airco'] = label_encoder.fit_transform(df['airco'])
df['prefarea'] = label_encoder.fit_transform(df['prefarea'])

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'rownames'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'lotsize'}>,
#         <Axes: title={'center': 'bedrooms'}>],
#        [<Axes: title={'center': 'bathrms'}>,
#         <Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'driveway'}>,
#         <Axes: title={'center': 'recroom'}>],
#        [<Axes: title={'center': 'fullbase'}>,
#         <Axes: title={'center': 'gashw'}>,
#         <Axes: title={'center': 'airco'}>,
#         <Axes: title={'center': 'garagepl'}>],
#        [<Axes: title={'center': 'prefarea'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
X = df.drop(['price'],axis=1)
Y = df["price"]
train_x, test_x, train_y, test_y = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
scalar = StandardScaler()
scalar.fit(train_x)
train_x = scalar.transform(train_x)
test_x = scalar.transform(test_x)

# %%
model1 = LinearRegression()
model1.fit(train_x, train_y)
predict_y_model1 = model1.predict(train_x)

# R squared error for Linear Regression
score_model1_1 = metrics.r2_score(train_y, predict_y_model1)
print("R squared error for Linear Regression: ", score_model1_1)

# Mean Absolute Error for Linear Regression
score_model1_2 = metrics.mean_absolute_error(train_y, predict_y_model1)
print('Mean Absolute Error for Linear Regression: ', score_model1_2)
# Out:
# R squared error for Linear Regression:  0.6787838461733429
# Mean Absolute Error for Linear Regression:  11236.9768991418

# %%
model2 = RandomForestRegressor(n_estimators=20, random_state=8)
model2.fit(train_x, train_y)
predict_y_model2 = model2.predict(train_x)

# R squared error for RANDOM FOREST REGRESSOR
score_model2_1 = metrics.r2_score(train_y, predict_y_model2)
print("R squared error for RANDOM FOREST REGRESSOR: ", score_model2_1)

# Mean Absolute Error for RANDOM FOREST REGRESSOR
score_model2_2 = metrics.mean_absolute_error(train_y, predict_y_model2)
print('Mean Absolute Error for RANDOM FOREST REGRESSOR: ', score_model2_2)
# Out:
# R squared error for RANDOM FOREST REGRESSOR:  0.9481807075721531
# Mean Absolute Error for RANDOM FOREST REGRESSOR:  4336.516972477064

# %%
model3 = XGBRegressor()
model3.fit(train_x, train_y)
predict_y_model3 = model3.predict(train_x)

# R squared error for XGBOOST
score_model3_1 = metrics.r2_score(train_y, predict_y_model3)
print("R squared error for XGBOOST: ", score_model3_1)

# Mean Absolute Error for XGBOOST
score_model3_2 = metrics.mean_absolute_error(train_y, predict_y_model3)
print('Mean Absolute Error for XGBOOST: ', score_model3_2)
# Out:
# R squared error for XGBOOST:  0.9995174894589496
# Mean Absolute Error for XGBOOST:  393.98922197534404

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.3.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 6.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 20.3 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
from sklearn.svm import SVR                          # For support vector regression
import xgboost as xgb                                # For XGBoost regression
import lightgbm as lgb                                # For LightGBM regression
from catboost import CatBoostRegressor               # For CatBoost regression

# Import modules for advanced model stacking techniques
from sklearn.ensemble import StackingRegressor        # For stacking multiple regressors
from mlxtend.regressor import StackingCVRegressor     # For stacked generalization with cross-validation

# Import additional libraries for hyperparameter tuning
import optuna    # For hyperparameter optimization

# Import metrics for additional model evaluation
from sklearn import metrics
# Import category_encoders for encoding categorical features
import category_encoders as ce

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# Create copies of the DataFrame for different preprocessing approaches
df_copy = df.copy()
df_boost = df.copy()
df_cat = df.copy()
df_rf = df.copy()

# %%
models = ["linear_regression", "random_forest", "xgboost", "lightgbm", "catboost", "catboost_custom"]


# Iterate through each model in the list
for model in models:
    if model == "linear_regression":
        # Preprocessing for linear regression and SVR

        # Fill missing values with mean for numerical columns and mode for categorical columns
        for col in df_copy.columns:
            if df_copy[col].dtype in ['int64', 'float64']:
                df_copy[col] = df_copy[col].fillna(df_copy[col].mean())
            elif df_copy[col].dtype == 'object':
                df_copy[col] = df_copy[col].fillna(df_copy[col].mode().iloc[0])
        df_copy.drop_duplicates(inplace=True)
        df_copy = pd.get_dummies(df_copy, drop_first=True)
    elif model in ["xgboost", "lightgbm", "catboost"]:

        dum_data = pd.get_dummies(df_boost, drop_first=True)
    elif model == "random_forest":
        if df_rf[col].dtype in ['int64', 'float64']:
                df_rf[col] = df_rf[col].fillna(df_rf[col].mean())
        elif df_rf[col].dtype == 'object':
                df_rf[col] = df_rf[col].fillna(df_rf[col].mode().iloc[0])
        df_rf = pd.get_dummies(df_rf, drop_first=True)



# Split data into features (X) and target (y) for each preprocessing approach
x_log = df_copy.drop(columns=['price'])
y_log = df_copy['price']
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(x_log, y_log, test_size=0.3, random_state=42)

x_boost = dum_data.drop(columns=['price'])
y_boost = dum_data['price']
X_train_boost, X_test_boost, y_train_boost, y_test_boost = train_test_split(x_boost, y_boost, test_size=0.3, random_state=42)

x_rf = df_rf.drop(columns=['price'])
y_rf = df_rf['price']
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(x_rf, y_rf, test_size=0.3, random_state=42)

x_cat = dum_data.drop(columns=['price'])
y_cat = dum_data['price']
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(x_cat, y_cat, test_size=0.3, random_state=42)

# %%
models = []

# Define default models for each algorithm
xgb_model_def = xgb.XGBRegressor()
lgb_model_def = lgb.LGBMRegressor()
catboost_model_def = CatBoostRegressor()
lg = LinearRegression()
rf = RandomForestRegressor()

# Define models for stacking
stacking_models = [('XGBoost', xgb_model_def),
                   ('LightGBM', lgb_model_def),
                   ('CatBoost', catboost_model_def),
                   ('LinearRegression', lg),
                   ('RandomForest', rf)]  # Add SVR to stacking_models

# Extend models list with default models
models.extend([
    ('XGBoost', xgb_model_def),
    ('LightGBM', lgb_model_def),
    ('CatBoost', catboost_model_def),
    ('LinearRegression', lg),
    ('RandomForest', rf),
])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
def train_and_evaluate_model(model_name, model, X_train, y_train, X_test, y_test):
    """
    Train and evaluate the given model on the training and testing data.

    Parameters:
    model_name (str): Name of the model for display purposes.
    model : Machine learning model object.
    X_train : Features of the training data.
    y_train : Target labels of the training data.
    X_test : Features of the testing data.
    y_test : Target labels of the testing data.

    Returns:
    float: R-squared score calculated from the model's predictions.
    """

    # Fit the model on the training data
    model.fit(X_train, y_train)

    # Predict labels on the testing data
    y_pred = model.predict(X_test)

    # Calculate evaluation metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Print model performance metrics
    print(f'Model Performance for {model_name}')
    print('Mean Absolute Error:', mae)
    print('Mean Squared Error:', mse)
    print('R-squared:', r2)

    return r2

# %%
r2_df = pd.DataFrame(columns=['Model', 'R2'])

# Iterate through each model in the list of models
for model_name, model in models:
    # Train and evaluate the model, and calculate the R-squared score
    if model_name == 'CatBoost':
        r2_score_value = train_and_evaluate_model(model_name, model, X_train_cat, y_train_cat, X_test_cat, y_test_cat)
    elif model_name in ['LinearRegression']:
        r2_score_value = train_and_evaluate_model(model_name, model, X_train_log, y_train_log, X_test_log, y_test_log)
    elif model_name == 'random_forest':
        r2_score_value = train_and_evaluate_model(model_name, model, X_train_rf, y_train_rf, X_test_rf, y_test_rf)
    else:
        r2_score_value = train_and_evaluate_model(model_name, model, X_train_boost, y_train_boost, X_test_boost, y_test_boost)

    # Add model name and R2 score to the DataFrame
    if r2_score_value is not None:
        r2_df = pd.concat([r2_df, pd.DataFrame({'Model': [model_name], 'R2': [r2_score_value]})], ignore_index=True)

# Sort the DataFrame by R2 score in descending order
r2_df_sorted = r2_df.sort_values(by='R2', ascending=False)
# Out:
# Model Performance for XGBoost
# Mean Absolute Error: 12998.995665015244
# Mean Squared Error: 343600895.9497563
# R-squared: 0.5965352478089017
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000394 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 249
# [LightGBM] [Info] Number of data points in the train set: 382, number of used features: 11
# [LightGBM] [Info] Start training from score 68007.321990
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Model Performance for LightGBM
# Mean Absolute Error: 11913.817912083085
# Mean Squared Error: 298206925.3810632
# R-squared: 0.6498379815978901
# Learning rate set to 0.035168
# 0:	learn: 25134.0386167	total: 48ms	remaining: 48s
# 1:	learn: 24731.1137888	total: 50ms	remaining: 24.9s
# 2:	learn: 24359.1603621	total: 53.6ms	remaining: 17.8s
# 3:	learn: 23997.7363553	total: 54.6ms	remaining: 13.6s
# 4:	learn: 23655.0548669	total: 56ms	remaining: 11.1s
# 5:	learn: 23330.1980991	total: 57.3ms	remaining: 9.49s
# 6:	learn: 23018.3857387	total: 58.5ms	remaining: 8.29s
# 7:	learn: 22680.5485367	total: 60.3ms	remaining: 7.48s
# 8:	learn: 22380.8412625	total: 61.5ms	remaining: 6.77s
# 9:	learn: 22062.7694060	total: 62.8ms	remaining: 6.21s
# 10:	learn: 21789.2414677	total: 64.2ms	remaining: 5.78s
# 11:	learn: 21540.2115267	total: 65ms	remaining: 5.35s
# 12:	learn: 21255.4426411	total: 66.3ms	remaining: 5.04s
# 13:	learn: 21003.8439419	total: 67.8ms	remaining: 4.78s
# 14:	learn: 20765.5452728	total: 69ms	remaining: 4.53s
# 15:	learn: 20512.6716718	total: 70.2ms	remaining: 4.32s
# 16:	learn: 20287.5773098	total: 71.3ms	remaining: 4.12s
# 17:	learn: 20066.2339250	total: 72.3ms	remaining: 3.95s
# 18:	learn: 19836.2065374	total: 73.3ms	remaining: 3.79s
# 19:	learn: 19627.7768266	total: 74.3ms	remaining: 3.64s
# 20:	learn: 19418.0853775	total: 75.3ms	remaining: 3.51s
# 21:	learn: 19165.8908933	total: 76.3ms	remaining: 3.39s
# 22:	learn: 19010.1679343	total: 76.9ms	remaining: 3.27s
# 23:	learn: 18844.0847873	total: 77.9ms	remaining: 3.17s
# 24:	learn: 18675.8962206	total: 79ms	remaining: 3.08s
# 25:	learn: 18488.7566799	total: 80.1ms	remaining: 3s
# 26:	learn: 18340.6988894	total: 81.1ms	remaining: 2.92s
# 27:	learn: 18148.1782639	total: 82.1ms	remaining: 2.85s
# 28:	learn: 18039.7214308	total: 82.6ms	remaining: 2.77s
# 29:	learn: 17880.4583475	total: 83.6ms	remaining: 2.7s
# 30:	learn: 17749.7748532	total: 84.7ms	remaining: 2.65s
# 31:	learn: 17606.6113709	total: 85.7ms	remaining: 2.59s
# 32:	learn: 17460.0159557	total: 86.7ms	remaining: 2.54s
# 33:	learn: 17317.4708473	total: 87.7ms	remaining: 2.49s
# 34:	learn: 17189.7077727	total: 88.7ms	remaining: 2.44s
# 35:	learn: 17069.7981686	total: 89.7ms	remaining: 2.4s
# 36:	learn: 16952.3661372	total: 90.6ms	remaining: 2.36s
# 37:	learn: 16816.8670759	total: 91.6ms	remaining: 2.32s
# 38:	learn: 16674.6556202	total: 92.6ms	remaining: 2.28s
# 39:	learn: 16549.8303364	total: 93.6ms	remaining: 2.25s
# 40:	learn: 16433.8808957	total: 94.6ms	remaining: 2.21s
# 41:	learn: 16331.7446945	total: 95.6ms	remaining: 2.18s
# 42:	learn: 16218.2433454	total: 96.6ms	remaining: 2.15s
# 43:	learn: 16114.6433946	total: 97.7ms	remaining: 2.12s
# 44:	learn: 15987.6900147	total: 98.7ms	remaining: 2.09s
# 45:	learn: 15894.2764408	total: 99.7ms	remaining: 2.07s
# 46:	learn: 15812.3591054	total: 100ms	remaining: 2.03s
# 47:	learn: 15715.0930698	total: 101ms	remaining: 2.01s
# 48:	learn: 15609.4770175	total: 102ms	remaining: 1.99s
# 49:	learn: 15523.1663000	total: 103ms	remaining: 1.96s
# 50:	learn: 15437.7790612	total: 104ms	remaining: 1.94s
# 51:	learn: 15339.8777610	total: 105ms	remaining: 1.92s
# 52:	learn: 15256.4723840	total: 106ms	remaining: 1.9s
# 53:	learn: 15168.0105672	total: 107ms	remaining: 1.88s
# 54:	learn: 15088.4210234	total: 108ms	remaining: 1.86s
# 55:	learn: 15030.7959416	total: 109ms	remaining: 1.84s
# 56:	learn: 14941.6384699	total: 110ms	remaining: 1.82s
# 57:	learn: 14862.2646038	total: 111ms	remaining: 1.81s
# 58:	learn: 14817.3682392	total: 112ms	remaining: 1.79s
# 59:	learn: 14753.0847448	total: 113ms	remaining: 1.78s
# 60:	learn: 14699.6451675	total: 118ms	remaining: 1.82s
# 61:	learn: 14619.8040919	total: 119ms	remaining: 1.8s
# 62:	learn: 14552.9596996	total: 120ms	remaining: 1.79s
# 63:	learn: 14465.7715814	total: 124ms	remaining: 1.81s
# 64:	learn: 14381.5042586	total: 128ms	remaining: 1.84s
# 65:	learn: 14305.5160724	total: 131ms	remaining: 1.85s
# 66:	learn: 14283.8386112	total: 132ms	remaining: 1.84s
# 67:	learn: 14205.2139151	total: 134ms	remaining: 1.83s
# 68:	learn: 14145.0372531	total: 135ms	remaining: 1.82s
# 69:	learn: 14088.6008219	total: 136ms	remaining: 1.8s
# 70:	learn: 14047.8190016	total: 138ms	remaining: 1.8s
# 71:	learn: 13979.4924250	total: 139ms	remaining: 1.78s
# 72:	learn: 13900.6977566	total: 140ms	remaining: 1.77s
# 73:	learn: 13864.1726892	total: 141ms	remaining: 1.76s
# 74:	learn: 13798.4430335	total: 142ms	remaining: 1.75s
# 75:	learn: 13740.2096090	total: 143ms	remaining: 1.74s
# 76:	learn: 13679.4339017	total: 144ms	remaining: 1.73s
# 77:	learn: 13625.8233547	total: 145ms	remaining: 1.72s
# 78:	learn: 13557.2321215	total: 146ms	remaining: 1.71s
# 79:	learn: 13503.5011997	total: 147ms	remaining: 1.7s
# 80:	learn: 13464.6932821	total: 148ms	remaining: 1.68s
# 81:	learn: 13373.4523796	total: 149ms	remaining: 1.67s
# 82:	learn: 13331.5489331	total: 150ms	remaining: 1.66s
# 83:	learn: 13299.5840307	total: 152ms	remaining: 1.65s
# 84:	learn: 13258.3831859	total: 153ms	remaining: 1.65s
# 85:	learn: 13216.1374534	total: 155ms	remaining: 1.65s
# 86:	learn: 13194.4084052	total: 155ms	remaining: 1.63s
# 87:	learn: 13132.8900043	total: 156ms	remaining: 1.61s
# 88:	learn: 13107.0942079	total: 157ms	remaining: 1.61s
# 89:	learn: 13073.7502790	total: 158ms	remaining: 1.6s
# 90:	learn: 13032.9032125	total: 159ms	remaining: 1.59s
# 91:	learn: 13004.7130739	total: 160ms	remaining: 1.58s
# 92:	learn: 12954.3670551	total: 162ms	remaining: 1.58s
# 93:	learn: 12897.8704695	total: 164ms	remaining: 1.58s
# 94:	learn: 12849.0391903	total: 165ms	remaining: 1.57s
# 95:	learn: 12806.7557553	total: 166ms	remaining: 1.57s
# 96:	learn: 12784.9502191	total: 167ms	remaining: 1.56s
# 97:	learn: 12719.0889967	total: 168ms	remaining: 1.54s
# 98:	learn: 12696.8706462	total: 169ms	remaining: 1.54s
# 99:	learn: 12669.0409509	total: 170ms	remaining: 1.53s
# 100:	learn: 12619.7830157	total: 171ms	remaining: 1.52s
# 101:	learn: 12593.7850237	total: 172ms	remaining: 1.52s
# 102:	learn: 12551.8381956	total: 174ms	remaining: 1.52s
# 103:	learn: 12543.7558040	total: 175ms	remaining: 1.51s
# 104:	learn: 12509.1506683	total: 177ms	remaining: 1.5s
# 105:	learn: 12455.6708826	total: 178ms	remaining: 1.5s
# 106:	learn: 12423.5990149	total: 179ms	remaining: 1.49s
# 107:	learn: 12406.6052073	total: 179ms	remaining: 1.48s
# 108:	learn: 12374.0285493	total: 180ms	remaining: 1.47s
# 109:	learn: 12354.9640217	total: 181ms	remaining: 1.47s
# 110:	learn: 12333.8394672	total: 183ms	remaining: 1.46s
# 111:	learn: 12301.3212152	total: 184ms	remaining: 1.46s
# 112:	learn: 12268.7530086	total: 184ms	remaining: 1.45s
# 113:	learn: 12233.1898954	total: 185ms	remaining: 1.44s
# 114:	learn: 12195.5828027	total: 186ms	remaining: 1.44s
# 115:	learn: 12170.9409281	total: 187ms	remaining: 1.43s
# 116:	learn: 12115.1274456	total: 188ms	remaining: 1.42s
# 117:	learn: 12081.3500113	total: 189ms	remaining: 1.42s
# 118:	learn: 12036.6606284	total: 190ms	remaining: 1.41s
# 119:	learn: 12021.6135102	total: 191ms	remaining: 1.4s
# 120:	learn: 11994.0820948	total: 192ms	remaining: 1.4s
# 121:	learn: 11974.3801946	total: 193ms	remaining: 1.39s
# 122:	learn: 11942.9665961	total: 194ms	remaining: 1.38s
# 123:	learn: 11916.1576584	total: 195ms	remaining: 1.38s
# 124:	learn: 11872.2791087	total: 196ms	remaining: 1.37s
# 125:	learn: 11838.9823227	total: 197ms	remaining: 1.36s
# 126:	learn: 11835.2212144	total: 197ms	remaining: 1.36s
# 127:	learn: 11818.6203542	total: 198ms	remaining: 1.35s
# 128:	learn: 11772.1647410	total: 199ms	remaining: 1.34s
# 129:	learn: 11746.6340188	total: 200ms	remaining: 1.34s
# 130:	learn: 11709.4183522	total: 201ms	remaining: 1.33s
# 131:	learn: 11672.0175584	total: 202ms	remaining: 1.33s
# 132:	learn: 11639.9333888	total: 203ms	remaining: 1.32s
# 133:	learn: 11609.0990564	total: 204ms	remaining: 1.32s
# 134:	learn: 11567.9986059	total: 205ms	remaining: 1.32s
# 135:	learn: 11543.2644373	total: 207ms	remaining: 1.31s
# 136:	learn: 11525.8504402	total: 208ms	remaining: 1.31s
# 137:	learn: 11484.7712533	total: 209ms	remaining: 1.3s
# 138:	learn: 11455.5273783	total: 210ms	remaining: 1.3s
# 139:	learn: 11430.8047814	total: 211ms	remaining: 1.29s
# 140:	learn: 11407.2918009	total: 212ms	remaining: 1.29s
# 141:	learn: 11363.4366483	total: 213ms	remaining: 1.28s
# 142:	learn: 11348.0221620	total: 214ms	remaining: 1.28s
# 143:	learn: 11315.0308919	total: 215ms	remaining: 1.28s
# 144:	learn: 11287.1153326	total: 216ms	remaining: 1.27s
# 145:	learn: 11263.1713723	total: 217ms	remaining: 1.27s
# 146:	learn: 11237.1353941	total: 218ms	remaining: 1.26s
# 147:	learn: 11200.2571157	total: 219ms	remaining: 1.26s
# 148:	learn: 11186.9825386	total: 220ms	remaining: 1.25s
# 149:	learn: 11143.7433794	total: 221ms	remaining: 1.25s
# 150:	learn: 11118.7596856	total: 222ms	remaining: 1.25s
# 151:	learn: 11103.7961613	total: 223ms	remaining: 1.24s
# 152:	learn: 11060.9014713	total: 224ms	remaining: 1.24s
# 153:	learn: 11050.2676713	total: 225ms	remaining: 1.23s
# 154:	learn: 11022.3757805	total: 226ms	remaining: 1.23s
# 155:	learn: 11000.4252924	total: 227ms	remaining: 1.23s
# 156:	learn: 10963.8844129	total: 228ms	remaining: 1.22s
# 157:	learn: 10940.3744829	total: 229ms	remaining: 1.22s
# 158:	learn: 10922.3225171	total: 230ms	remaining: 1.21s
# 159:	learn: 10909.2306435	total: 231ms	remaining: 1.21s
# 160:	learn: 10897.8862165	total: 231ms	remaining: 1.21s
# 161:	learn: 10873.5452704	total: 232ms	remaining: 1.2s
# 162:	learn: 10856.4649878	total: 233ms	remaining: 1.2s
# 163:	learn: 10823.0829888	total: 234ms	remaining: 1.19s
# 164:	learn: 10810.9994193	total: 235ms	remaining: 1.19s
# 165:	learn: 10775.1855064	total: 236ms	remaining: 1.19s
# 166:	learn: 10753.0345664	total: 237ms	remaining: 1.18s
# 167:	learn: 10718.4475015	total: 238ms	remaining: 1.18s
# 168:	learn: 10708.9371783	total: 241ms	remaining: 1.19s
# 169:	learn: 10689.3297410	total: 242ms	remaining: 1.18s
# 170:	learn: 10670.3615468	total: 245ms	remaining: 1.19s
# 171:	learn: 10647.4118580	total: 246ms	remaining: 1.19s
# 172:	learn: 10621.1899583	total: 247ms	remaining: 1.18s
# 173:	learn: 10596.2724166	total: 248ms	remaining: 1.18s
# 174:	learn: 10574.1446189	total: 249ms	remaining: 1.18s
# 175:	learn: 10554.2578552	total: 250ms	remaining: 1.17s
# 176:	learn: 10523.6959267	total: 251ms	remaining: 1.17s
# 177:	learn: 10505.0101312	total: 252ms	remaining: 1.17s
# 178:	learn: 10482.5911152	total: 253ms	remaining: 1.16s
# 179:	learn: 10460.0863940	total: 254ms	remaining: 1.16s
# 180:	learn: 10428.5692895	total: 255ms	remaining: 1.16s
# 181:	learn: 10412.4636475	total: 256ms	remaining: 1.15s
# 182:	learn: 10400.4679915	total: 257ms	remaining: 1.15s
# 183:	learn: 10387.0041100	total: 258ms	remaining: 1.15s
# 184:	learn: 10364.5697984	total: 259ms	remaining: 1.14s
# 185:	learn: 10339.8206013	total: 260ms	remaining: 1.14s
# 186:	learn: 10321.8757116	total: 261ms	remaining: 1.14s
# 187:	learn: 10309.5432163	total: 262ms	remaining: 1.13s
# 188:	learn: 10297.8404329	total: 263ms	remaining: 1.13s
# 189:	learn: 10289.3901705	total: 264ms	remaining: 1.13s
# 190:	learn: 10259.2471016	total: 265ms	remaining: 1.12s
# 191:	learn: 10235.5236683	total: 266ms	remaining: 1.12s
# 192:	learn: 10210.5140093	total: 267ms	remaining: 1.12s
# 193:	learn: 10195.4537711	total: 268ms	remaining: 1.11s
# 194:	learn: 10185.9210051	total: 269ms	remaining: 1.11s
# 195:	learn: 10167.0519664	total: 270ms	remaining: 1.11s
# 196:	learn: 10157.7477122	total: 271ms	remaining: 1.1s
# 197:	learn: 10145.1617015	total: 272ms	remaining: 1.1s
# 198:	learn: 10134.1193803	total: 273ms	remaining: 1.1s
# 199:	learn: 10101.7428732	total: 274ms	remaining: 1.1s
# 200:	learn: 10091.0744204	total: 275ms	remaining: 1.09s
# 201:	learn: 10080.8849400	total: 276ms	remaining: 1.09s
# 202:	learn: 10064.6049440	total: 277ms	remaining: 1.09s
# 203:	learn: 10055.0409881	total: 278ms	remaining: 1.08s
# 204:	learn: 10036.3677836	total: 279ms	remaining: 1.08s
# 205:	learn: 10016.7503977	total: 280ms	remaining: 1.08s
# 206:	learn: 9995.8236884	total: 281ms	remaining: 1.08s
# 207:	learn: 9977.8896796	total: 282ms	remaining: 1.07s
# 208:	learn: 9951.6152111	total: 283ms	remaining: 1.07s
# 209:	learn: 9923.5408197	total: 284ms	remaining: 1.07s
# 210:	learn: 9914.7917172	total: 285ms	remaining: 1.06s
# 211:	learn: 9901.2296229	total: 287ms	remaining: 1.07s
# 212:	learn: 9875.5718014	total: 289ms	remaining: 1.07s
# 213:	learn: 9856.6979841	total: 292ms	remaining: 1.07s
# 214:	learn: 9848.1819559	total: 292ms	remaining: 1.07s
# 215:	learn: 9829.7962312	total: 293ms	remaining: 1.06s
# 216:	learn: 9819.5684295	total: 294ms	remaining: 1.06s
# 217:	learn: 9805.1982981	total: 295ms	remaining: 1.06s
# 218:	learn: 9789.9095691	total: 296ms	remaining: 1.06s
# 219:	learn: 9783.1322148	total: 297ms	remaining: 1.05s
# 220:	learn: 9768.1751647	total: 298ms	remaining: 1.05s
# 221:	learn: 9747.1658203	total: 299ms	remaining: 1.05s
# 222:	learn: 9724.4820960	total: 300ms	remaining: 1.05s
# 223:	learn: 9710.0212773	total: 301ms	remaining: 1.04s
# 224:	learn: 9703.4244720	total: 302ms	remaining: 1.04s
# 225:	learn: 9682.3646167	total: 303ms	remaining: 1.04s
# 226:	learn: 9659.5761818	total: 304ms	remaining: 1.04s
# 227:	learn: 9643.1661798	total: 306ms	remaining: 1.03s
# 228:	learn: 9632.0480422	total: 307ms	remaining: 1.03s
# 229:	learn: 9606.8428055	total: 308ms	remaining: 1.03s
# 230:	learn: 9578.4901309	total: 309ms	remaining: 1.03s
# 231:	learn: 9568.1861375	total: 310ms	remaining: 1.02s
# 232:	learn: 9533.9461525	total: 311ms	remaining: 1.02s
# 233:	learn: 9518.9628367	total: 312ms	remaining: 1.02s
# 234:	learn: 9504.8321010	total: 313ms	remaining: 1.02s
# 235:	learn: 9484.3233094	total: 314ms	remaining: 1.01s
# 236:	learn: 9470.4492939	total: 315ms	remaining: 1.01s
# 237:	learn: 9461.6398109	total: 316ms	remaining: 1.01s
# 238:	learn: 9456.1562958	total: 317ms	remaining: 1.01s
# 239:	learn: 9446.7191012	total: 318ms	remaining: 1.01s
# 240:	learn: 9425.7597628	total: 319ms	remaining: 1s
# 241:	learn: 9413.2933841	total: 320ms	remaining: 1s
# 242:	learn: 9402.0821492	total: 321ms	remaining: 999ms
# 243:	learn: 9390.1647265	total: 322ms	remaining: 997ms
# 244:	learn: 9375.4312310	total: 323ms	remaining: 995ms
# 245:	learn: 9358.4923390	total: 324ms	remaining: 992ms
# 246:	learn: 9345.4299719	total: 325ms	remaining: 990ms
# 247:	learn: 9335.7944279	total: 326ms	remaining: 988ms
# 248:	learn: 9308.5132939	total: 327ms	remaining: 986ms
# 249:	learn: 9293.5315482	total: 328ms	remaining: 984ms
# 250:	learn: 9277.3639846	total: 329ms	remaining: 981ms
# 251:	learn: 9267.3097311	total: 330ms	remaining: 979ms
# 252:	learn: 9258.8575625	total: 331ms	remaining: 977ms
# 253:	learn: 9248.3389705	total: 332ms	remaining: 974ms
# 254:	learn: 9241.8001500	total: 333ms	remaining: 972ms
# 255:	learn: 9214.1054637	total: 334ms	remaining: 970ms
# 256:	learn: 9190.1487869	total: 335ms	remaining: 968ms
# 257:	learn: 9170.7564116	total: 336ms	remaining: 966ms
# 258:	learn: 9159.8645387	total: 337ms	remaining: 963ms
# 259:	learn: 9145.5634073	total: 338ms	remaining: 961ms
# 260:	learn: 9136.8101526	total: 339ms	remaining: 959ms
# 261:	learn: 9117.6149328	total: 340ms	remaining: 957ms
# 262:	learn: 9101.1446544	total: 341ms	remaining: 954ms
# 263:	learn: 9079.1752824	total: 342ms	remaining: 952ms
# 264:	learn: 9068.7432837	total: 343ms	remaining: 951ms
# 265:	learn: 9043.9557107	total: 344ms	remaining: 949ms
# 266:	learn: 9028.7536842	total: 345ms	remaining: 946ms
# 267:	learn: 9023.5297615	total: 346ms	remaining: 944ms
# 268:	learn: 9015.6232311	total: 347ms	remaining: 942ms
# 269:	learn: 9007.7980033	total: 348ms	remaining: 940ms
# 270:	learn: 8998.6389482	total: 350ms	remaining: 941ms
# 271:	learn: 8992.1069143	total: 351ms	remaining: 939ms
# 272:	learn: 8970.6597291	total: 352ms	remaining: 938ms
# 273:	learn: 8963.9214204	total: 353ms	remaining: 936ms
# 274:	learn: 8941.8251719	total: 354ms	remaining: 934ms
# 275:	learn: 8932.6250901	total: 355ms	remaining: 932ms
# 276:	learn: 8914.9101748	total: 356ms	remaining: 930ms
# 277:	learn: 8900.1120362	total: 357ms	remaining: 927ms
# 278:	learn: 8889.1527103	total: 358ms	remaining: 925ms
# 279:	learn: 8883.8033395	total: 359ms	remaining: 923ms
# 280:	learn: 8869.4240202	total: 360ms	remaining: 921ms
# 281:	learn: 8846.0314371	total: 361ms	remaining: 919ms
# 282:	learn: 8832.3040732	total: 362ms	remaining: 917ms
# 283:	learn: 8803.6910209	total: 363ms	remaining: 915ms
# 284:	learn: 8780.2222864	total: 364ms	remaining: 913ms
# 285:	learn: 8765.4412901	total: 365ms	remaining: 911ms
# 286:	learn: 8760.8515856	total: 366ms	remaining: 908ms
# 287:	learn: 8752.3393156	total: 367ms	remaining: 907ms
# 288:	learn: 8745.1402057	total: 368ms	remaining: 905ms
# 289:	learn: 8737.2182274	total: 369ms	remaining: 903ms
# 290:	learn: 8731.3869441	total: 370ms	remaining: 901ms
# 291:	learn: 8714.9494666	total: 371ms	remaining: 899ms
# 292:	learn: 8704.1009287	total: 372ms	remaining: 897ms
# 293:	learn: 8694.7665720	total: 373ms	remaining: 895ms
# 294:	learn: 8685.4916493	total: 374ms	remaining: 893ms
# 295:	learn: 8680.9067738	total: 375ms	remaining: 891ms
# 296:	learn: 8677.0245139	total: 376ms	remaining: 889ms
# 297:	learn: 8669.0140057	total: 377ms	remaining: 888ms
# 298:	learn: 8658.1364168	total: 378ms	remaining: 886ms
# 299:	learn: 8639.4759064	total: 379ms	remaining: 884ms
# 300:	learn: 8630.0173290	total: 380ms	remaining: 882ms
# 301:	learn: 8620.1609216	total: 381ms	remaining: 880ms
# 302:	learn: 8603.6281552	total: 382ms	remaining: 878ms
# 303:	learn: 8593.5058201	total: 383ms	remaining: 876ms
# 304:	learn: 8580.5772288	total: 384ms	remaining: 875ms
# 305:	learn: 8571.4662688	total: 385ms	remaining: 873ms
# 306:	learn: 8562.2485125	total: 386ms	remaining: 871ms
# 307:	learn: 8548.8629480	total: 387ms	remaining: 869ms
# 308:	learn: 8540.7675519	total: 388ms	remaining: 868ms
# 309:	learn: 8537.5488393	total: 389ms	remaining: 866ms
# 310:	learn: 8524.3494544	total: 390ms	remaining: 864ms
# 311:	learn: 8519.4309760	total: 391ms	remaining: 863ms
# 312:	learn: 8505.5703440	total: 392ms	remaining: 861ms
# 313:	learn: 8497.3470045	total: 393ms	remaining: 860ms
# 314:	learn: 8488.4864306	total: 395ms	remaining: 858ms
# 315:	learn: 8468.3410446	total: 395ms	remaining: 856ms
# 316:	learn: 8456.6160160	total: 396ms	remaining: 854ms
# 317:	learn: 8449.9742127	total: 397ms	remaining: 852ms
# 318:	learn: 8445.6801335	total: 398ms	remaining: 851ms
# 319:	learn: 8435.3642620	total: 399ms	remaining: 849ms
# 320:	learn: 8426.5144041	total: 401ms	remaining: 848ms
# 321:	learn: 8418.4128116	total: 402ms	remaining: 846ms
# 322:	learn: 8415.5183668	total: 403ms	remaining: 844ms
# 323:	learn: 8411.4784925	total: 404ms	remaining: 844ms
# 324:	learn: 8394.8362702	total: 405ms	remaining: 841ms
# 325:	learn: 8385.1424428	total: 406ms	remaining: 840ms
# 326:	learn: 8381.3112304	total: 407ms	remaining: 839ms
# 327:	learn: 8369.7301363	total: 409ms	remaining: 837ms
# 328:	learn: 8350.0992193	total: 410ms	remaining: 837ms
# 329:	learn: 8343.6766555	total: 412ms	remaining: 837ms
# 330:	learn: 8340.7100382	total: 413ms	remaining: 835ms
# 331:	learn: 8330.1049518	total: 414ms	remaining: 833ms
# 332:	learn: 8321.9533357	total: 415ms	remaining: 831ms
# 333:	learn: 8310.4767353	total: 416ms	remaining: 829ms
# 334:	learn: 8300.8841131	total: 417ms	remaining: 827ms
# 335:	learn: 8290.4886877	total: 418ms	remaining: 825ms
# 336:	learn: 8277.3388817	total: 421ms	remaining: 829ms
# 337:	learn: 8266.1797721	total: 425ms	remaining: 831ms
# 338:	learn: 8254.0804392	total: 426ms	remaining: 830ms
# 339:	learn: 8238.0769675	total: 427ms	remaining: 828ms
# 340:	learn: 8233.6050882	total: 428ms	remaining: 826ms
# 341:	learn: 8224.4223025	total: 429ms	remaining: 825ms
# 342:	learn: 8216.9696741	total: 430ms	remaining: 823ms
# 343:	learn: 8197.8203614	total: 431ms	remaining: 821ms
# 344:	learn: 8187.2412298	total: 432ms	remaining: 819ms
# 345:	learn: 8164.5448364	total: 433ms	remaining: 818ms
# 346:	learn: 8158.8607585	total: 434ms	remaining: 816ms
# 347:	learn: 8149.2439638	total: 435ms	remaining: 814ms
# 348:	learn: 8142.6486944	total: 436ms	remaining: 812ms
# 349:	learn: 8135.1813948	total: 436ms	remaining: 811ms
# 350:	learn: 8122.9757515	total: 437ms	remaining: 809ms
# 351:	learn: 8115.8839468	total: 438ms	remaining: 807ms
# 352:	learn: 8106.6021967	total: 439ms	remaining: 805ms
# 353:	learn: 8090.7130489	total: 440ms	remaining: 804ms
# 354:	learn: 8082.5289568	total: 441ms	remaining: 802ms
# 355:	learn: 8075.4715437	total: 442ms	remaining: 800ms
# 356:	learn: 8072.8741496	total: 443ms	remaining: 798ms
# 357:	learn: 8050.4197874	total: 444ms	remaining: 796ms
# 358:	learn: 8037.9337409	total: 445ms	remaining: 795ms
# 359:	learn: 8027.9972693	total: 446ms	remaining: 793ms
# 360:	learn: 8020.8350295	total: 447ms	remaining: 791ms
# 361:	learn: 8008.8225074	total: 448ms	remaining: 790ms
# 362:	learn: 7991.7500994	total: 449ms	remaining: 788ms
# 363:	learn: 7978.1442316	total: 450ms	remaining: 786ms
# 364:	learn: 7971.0387702	total: 451ms	remaining: 784ms
# 365:	learn: 7964.3860395	total: 452ms	remaining: 783ms
# 366:	learn: 7957.7250327	total: 453ms	remaining: 782ms
# 367:	learn: 7943.7589747	total: 455ms	remaining: 781ms
# 368:	learn: 7926.6462030	total: 456ms	remaining: 779ms
# 369:	learn: 7919.0328725	total: 457ms	remaining: 778ms
# 370:	learn: 7913.5952536	total: 458ms	remaining: 777ms
# 371:	learn: 7911.1582535	total: 459ms	remaining: 775ms
# 372:	learn: 7902.0857042	total: 460ms	remaining: 773ms
# 373:	learn: 7895.1524702	total: 461ms	remaining: 772ms
# 374:	learn: 7892.4420219	total: 462ms	remaining: 770ms
# 375:	learn: 7890.4219731	total: 463ms	remaining: 768ms
# 376:	learn: 7874.9026780	total: 464ms	remaining: 767ms
# 377:	learn: 7862.3979129	total: 465ms	remaining: 765ms
# 378:	learn: 7851.8640938	total: 466ms	remaining: 763ms
# 379:	learn: 7849.7060989	total: 467ms	remaining: 762ms
# 380:	learn: 7830.4847788	total: 468ms	remaining: 760ms
# 381:	learn: 7822.4503120	total: 469ms	remaining: 758ms
# 382:	learn: 7813.4095958	total: 470ms	remaining: 757ms
# 383:	learn: 7801.4696113	total: 471ms	remaining: 755ms
# 384:	learn: 7793.2783215	total: 472ms	remaining: 754ms
# 385:	learn: 7781.7474591	total: 473ms	remaining: 752ms
# 386:	learn: 7770.2733335	total: 474ms	remaining: 750ms
# 387:	learn: 7755.0542274	total: 475ms	remaining: 749ms
# 388:	learn: 7749.6647387	total: 476ms	remaining: 747ms
# 389:	learn: 7741.6425362	total: 477ms	remaining: 745ms
# 390:	learn: 7739.2268729	total: 477ms	remaining: 744ms
# 391:	learn: 7734.2363694	total: 478ms	remaining: 742ms
# 392:	learn: 7726.1924153	total: 479ms	remaining: 740ms
# 393:	learn: 7718.6544035	total: 480ms	remaining: 739ms
# 394:	learn: 7712.6622257	total: 481ms	remaining: 737ms
# 395:	learn: 7704.5117170	total: 482ms	remaining: 736ms
# 396:	learn: 7695.2815127	total: 483ms	remaining: 734ms
# 397:	learn: 7686.1955822	total: 484ms	remaining: 732ms
# 398:	learn: 7675.3392503	total: 485ms	remaining: 731ms
# 399:	learn: 7664.7213051	total: 486ms	remaining: 729ms
# 400:	learn: 7658.8348328	total: 487ms	remaining: 728ms
# 401:	learn: 7649.8607294	total: 488ms	remaining: 726ms
# 402:	learn: 7641.7842513	total: 489ms	remaining: 724ms
# 403:	learn: 7635.6382631	total: 490ms	remaining: 723ms
# 404:	learn: 7633.1549916	total: 491ms	remaining: 721ms
# 405:	learn: 7625.0971167	total: 492ms	remaining: 720ms
# 406:	learn: 7618.3188796	total: 493ms	remaining: 718ms
# 407:	learn: 7606.7484843	total: 494ms	remaining: 716ms
# 408:	learn: 7593.7521341	total: 495ms	remaining: 715ms
# 409:	learn: 7588.0006337	total: 496ms	remaining: 713ms
# 410:	learn: 7580.6209686	total: 497ms	remaining: 712ms
# 411:	learn: 7570.1651394	total: 498ms	remaining: 710ms
# 412:	learn: 7565.2509069	total: 499ms	remaining: 709ms
# 413:	learn: 7558.9404633	total: 500ms	remaining: 707ms
# 414:	learn: 7541.6298820	total: 501ms	remaining: 706ms
# 415:	learn: 7539.3062147	total: 502ms	remaining: 704ms
# 416:	learn: 7524.5153471	total: 503ms	remaining: 703ms
# 417:	learn: 7517.7460222	total: 504ms	remaining: 701ms
# 418:	learn: 7512.3052421	total: 505ms	remaining: 700ms
# 419:	learn: 7499.0199699	total: 505ms	remaining: 698ms
# 420:	learn: 7488.1648056	total: 506ms	remaining: 697ms
# 421:	learn: 7483.0235622	total: 507ms	remaining: 695ms
# 422:	learn: 7480.0986066	total: 508ms	remaining: 693ms
# 423:	learn: 7470.6043497	total: 509ms	remaining: 692ms
# 424:	learn: 7464.1131825	total: 510ms	remaining: 690ms
# 425:	learn: 7455.9081177	total: 511ms	remaining: 689ms
# 426:	learn: 7448.4044294	total: 512ms	remaining: 687ms
# 427:	learn: 7442.0124576	total: 513ms	remaining: 686ms
# 428:	learn: 7435.8787860	total: 514ms	remaining: 684ms
# 429:	learn: 7428.9325237	total: 515ms	remaining: 683ms
# 430:	learn: 7420.8446155	total: 516ms	remaining: 681ms
# 431:	learn: 7414.9065664	total: 517ms	remaining: 680ms
# 432:	learn: 7409.3973889	total: 518ms	remaining: 678ms
# 433:	learn: 7397.9033907	total: 519ms	remaining: 677ms
# 434:	learn: 7394.2782808	total: 520ms	remaining: 675ms
# 435:	learn: 7384.1562434	total: 521ms	remaining: 674ms
# 436:	learn: 7378.0192126	total: 522ms	remaining: 672ms
# 437:	learn: 7361.6554558	total: 523ms	remaining: 671ms
# 438:	learn: 7354.2826452	total: 524ms	remaining: 669ms
# 439:	learn: 7343.0527767	total: 525ms	remaining: 668ms
# 440:	learn: 7339.8699174	total: 526ms	remaining: 667ms
# 441:	learn: 7317.0970398	total: 527ms	remaining: 665ms
# 442:	learn: 7311.5880139	total: 528ms	remaining: 664ms
# 443:	learn: 7304.4696111	total: 529ms	remaining: 662ms
# 444:	learn: 7298.5854357	total: 530ms	remaining: 661ms
# 445:	learn: 7294.0486116	total: 530ms	remaining: 659ms
# 446:	learn: 7286.2690244	total: 531ms	remaining: 657ms
# 447:	learn: 7277.7169585	total: 532ms	remaining: 656ms
# 448:	learn: 7264.2169582	total: 533ms	remaining: 654ms
# 449:	learn: 7251.7151167	total: 534ms	remaining: 653ms
# 450:	learn: 7249.3268427	total: 535ms	remaining: 651ms
# 451:	learn: 7234.2798583	total: 536ms	remaining: 650ms
# 452:	learn: 7220.4574031	total: 537ms	remaining: 649ms
# 453:	learn: 7213.4032936	total: 538ms	remaining: 647ms
# 454:	learn: 7211.1259203	total: 539ms	remaining: 646ms
# 455:	learn: 7203.3624153	total: 540ms	remaining: 644ms
# 456:	learn: 7197.9788830	total: 541ms	remaining: 643ms
# 457:	learn: 7190.7100115	total: 542ms	remaining: 641ms
# 458:	learn: 7181.7451481	total: 543ms	remaining: 640ms
# 459:	learn: 7174.0563996	total: 544ms	remaining: 639ms
# 460:	learn: 7168.4493288	total: 545ms	remaining: 637ms
# 461:	learn: 7158.8794561	total: 546ms	remaining: 636ms
# 462:	learn: 7135.7398823	total: 547ms	remaining: 634ms
# 463:	learn: 7128.9402653	total: 548ms	remaining: 633ms
# 464:	learn: 7123.6785976	total: 549ms	remaining: 631ms
# 465:	learn: 7115.7865978	total: 550ms	remaining: 630ms
# 466:	learn: 7110.1390161	total: 551ms	remaining: 629ms
# 467:	learn: 7098.6486728	total: 552ms	remaining: 627ms
# 468:	learn: 7096.1181574	total: 553ms	remaining: 626ms
# 469:	learn: 7086.6422143	total: 554ms	remaining: 624ms
# 470:	learn: 7079.6835303	total: 555ms	remaining: 623ms
# 471:	learn: 7071.5459121	total: 556ms	remaining: 621ms
# 472:	learn: 7066.5151656	total: 556ms	remaining: 620ms
# 473:	learn: 7058.0921118	total: 557ms	remaining: 619ms
# 474:	learn: 7045.6519715	total: 558ms	remaining: 617ms
# 475:	learn: 7043.6393540	total: 559ms	remaining: 616ms
# 476:	learn: 7036.4730795	total: 560ms	remaining: 614ms
# 477:	learn: 7033.0121342	total: 561ms	remaining: 613ms
# 478:	learn: 7026.9544860	total: 562ms	remaining: 612ms
# 479:	learn: 7016.2429785	total: 563ms	remaining: 610ms
# 480:	learn: 7012.3720110	total: 564ms	remaining: 609ms
# 481:	learn: 7005.8199148	total: 565ms	remaining: 607ms
# 482:	learn: 7003.2031835	total: 566ms	remaining: 606ms
# 483:	learn: 6996.6166797	total: 567ms	remaining: 605ms
# 484:	learn: 6990.6499213	total: 568ms	remaining: 603ms
# 485:	learn: 6981.3409910	total: 569ms	remaining: 602ms
# 486:	learn: 6973.1408578	total: 570ms	remaining: 601ms
# 487:	learn: 6969.0021972	total: 571ms	remaining: 599ms
# 488:	learn: 6957.9621434	total: 572ms	remaining: 598ms
# 489:	learn: 6954.9293426	total: 573ms	remaining: 596ms
# 490:	learn: 6938.3361616	total: 574ms	remaining: 595ms
# 491:	learn: 6930.5023559	total: 575ms	remaining: 594ms
# 492:	learn: 6922.4192695	total: 576ms	remaining: 592ms
# 493:	learn: 6914.0315969	total: 577ms	remaining: 591ms
# 494:	learn: 6909.8342301	total: 578ms	remaining: 589ms
# 495:	learn: 6900.6705790	total: 579ms	remaining: 588ms
# 496:	learn: 6893.8672369	total: 580ms	remaining: 587ms
# 497:	learn: 6888.0701324	total: 581ms	remaining: 585ms
# 498:	learn: 6884.0771038	total: 582ms	remaining: 584ms
# 499:	learn: 6878.8542241	total: 583ms	remaining: 583ms
# 500:	learn: 6874.0406363	total: 584ms	remaining: 581ms
# 501:	learn: 6865.0747017	total: 585ms	remaining: 580ms
# 502:	learn: 6857.1835411	total: 586ms	remaining: 579ms
# 503:	learn: 6844.1639523	total: 587ms	remaining: 577ms
# 504:	learn: 6831.4636360	total: 588ms	remaining: 576ms
# 505:	learn: 6827.3287709	total: 588ms	remaining: 574ms
# 506:	learn: 6822.0461686	total: 589ms	remaining: 573ms
# 507:	learn: 6812.9304947	total: 590ms	remaining: 572ms
# 508:	learn: 6804.5357127	total: 591ms	remaining: 570ms
# 509:	learn: 6799.1656388	total: 592ms	remaining: 569ms
# 510:	learn: 6791.9903005	total: 593ms	remaining: 568ms
# 511:	learn: 6787.9673599	total: 594ms	remaining: 566ms
# 512:	learn: 6783.3086185	total: 595ms	remaining: 565ms
# 513:	learn: 6780.3292118	total: 596ms	remaining: 564ms
# 514:	learn: 6762.2912829	total: 597ms	remaining: 563ms
# 515:	learn: 6758.0891676	total: 599ms	remaining: 562ms
# 516:	learn: 6750.2868444	total: 602ms	remaining: 562ms
# 517:	learn: 6744.1029853	total: 603ms	remaining: 561ms
# 518:	learn: 6739.8364037	total: 604ms	remaining: 560ms
# 519:	learn: 6737.5272140	total: 607ms	remaining: 560ms
# 520:	learn: 6733.7247082	total: 609ms	remaining: 560ms
# 521:	learn: 6731.2570999	total: 611ms	remaining: 560ms
# 522:	learn: 6722.3067819	total: 612ms	remaining: 558ms
# 523:	learn: 6714.1041334	total: 613ms	remaining: 557ms
# 524:	learn: 6709.7469230	total: 614ms	remaining: 556ms
# 525:	learn: 6701.8189611	total: 615ms	remaining: 554ms
# 526:	learn: 6695.3471667	total: 616ms	remaining: 553ms
# 527:	learn: 6690.6490146	total: 617ms	remaining: 552ms
# 528:	learn: 6679.4483059	total: 618ms	remaining: 550ms
# 529:	learn: 6674.7855957	total: 619ms	remaining: 549ms
# 530:	learn: 6670.4954333	total: 620ms	remaining: 548ms
# 531:	learn: 6663.5776317	total: 621ms	remaining: 547ms
# 532:	learn: 6657.8759592	total: 622ms	remaining: 545ms
# 533:	learn: 6648.8858899	total: 623ms	remaining: 544ms
# 534:	learn: 6645.9824840	total: 625ms	remaining: 543ms
# 535:	learn: 6641.7566363	total: 626ms	remaining: 542ms
# 536:	learn: 6633.8709919	total: 627ms	remaining: 540ms
# 537:	learn: 6628.8806541	total: 628ms	remaining: 539ms
# 538:	learn: 6624.0609559	total: 629ms	remaining: 538ms
# 539:	learn: 6619.8947718	total: 630ms	remaining: 536ms
# 540:	learn: 6612.0200743	total: 631ms	remaining: 535ms
# 541:	learn: 6605.0010797	total: 632ms	remaining: 534ms
# 542:	learn: 6600.2572741	total: 633ms	remaining: 533ms
# 543:	learn: 6597.1913516	total: 634ms	remaining: 531ms
# 544:	learn: 6592.9029481	total: 635ms	remaining: 530ms
# 545:	learn: 6586.3861792	total: 636ms	remaining: 529ms
# 546:	learn: 6582.4376215	total: 637ms	remaining: 527ms
# 547:	learn: 6571.8620788	total: 638ms	remaining: 526ms
# 548:	learn: 6565.5800488	total: 639ms	remaining: 525ms
# 549:	learn: 6559.5835720	total: 640ms	remaining: 523ms
# 550:	learn: 6558.0607949	total: 641ms	remaining: 522ms
# 551:	learn: 6553.2977069	total: 642ms	remaining: 521ms
# 552:	learn: 6550.3282656	total: 643ms	remaining: 520ms
# 553:	learn: 6536.9476686	total: 644ms	remaining: 518ms
# 554:	learn: 6526.9277311	total: 645ms	remaining: 517ms
# 555:	learn: 6513.9896179	total: 646ms	remaining: 516ms
# 556:	learn: 6511.0997082	total: 647ms	remaining: 514ms
# 557:	learn: 6502.7485814	total: 648ms	remaining: 513ms
# 558:	learn: 6499.4326685	total: 649ms	remaining: 512ms
# 559:	learn: 6495.0693161	total: 650ms	remaining: 510ms
# 560:	learn: 6488.4389638	total: 650ms	remaining: 509ms
# 561:	learn: 6480.7916431	total: 651ms	remaining: 508ms
# 562:	learn: 6472.8983290	total: 652ms	remaining: 506ms
# 563:	learn: 6460.5359832	total: 653ms	remaining: 505ms
# 564:	learn: 6457.3850192	total: 654ms	remaining: 504ms
# 565:	learn: 6454.5514634	total: 655ms	remaining: 502ms
# 566:	learn: 6451.0701896	total: 656ms	remaining: 501ms
# 567:	learn: 6445.5165832	total: 657ms	remaining: 500ms
# 568:	learn: 6442.0636004	total: 658ms	remaining: 498ms
# 569:	learn: 6438.4403342	total: 659ms	remaining: 497ms
# 570:	learn: 6433.0118885	total: 660ms	remaining: 496ms
# 571:	learn: 6430.7016982	total: 661ms	remaining: 495ms
# 572:	learn: 6422.9176790	total: 662ms	remaining: 493ms
# 573:	learn: 6421.4990703	total: 663ms	remaining: 492ms
# 574:	learn: 6415.5138599	total: 664ms	remaining: 491ms
# 575:	learn: 6403.9952701	total: 665ms	remaining: 489ms
# 576:	learn: 6396.9037493	total: 666ms	remaining: 488ms
# 577:	learn: 6395.0748546	total: 667ms	remaining: 487ms
# 578:	learn: 6385.7665474	total: 668ms	remaining: 486ms
# 579:	learn: 6380.2969575	total: 669ms	remaining: 484ms
# 580:	learn: 6378.1681107	total: 670ms	remaining: 483ms
# 581:	learn: 6370.0117452	total: 671ms	remaining: 482ms
# 582:	learn: 6358.5204702	total: 672ms	remaining: 480ms
# 583:	learn: 6352.3452384	total: 673ms	remaining: 479ms
# 584:	learn: 6349.2828286	total: 674ms	remaining: 478ms
# 585:	learn: 6332.1033178	total: 675ms	remaining: 477ms
# 586:	learn: 6326.2781166	total: 676ms	remaining: 475ms
# 587:	learn: 6321.3140036	total: 677ms	remaining: 474ms
# 588:	learn: 6313.5630316	total: 678ms	remaining: 473ms
# 589:	learn: 6309.0662511	total: 679ms	remaining: 472ms
# 590:	learn: 6305.1770504	total: 680ms	remaining: 470ms
# 591:	learn: 6301.3967251	total: 681ms	remaining: 469ms
# 592:	learn: 6295.9772294	total: 682ms	remaining: 468ms
# 593:	learn: 6293.6243026	total: 683ms	remaining: 466ms
# 594:	learn: 6290.0932732	total: 683ms	remaining: 465ms
# 595:	learn: 6285.6880903	total: 684ms	remaining: 464ms
# 596:	learn: 6276.7506577	total: 685ms	remaining: 463ms
# 597:	learn: 6273.8768949	total: 686ms	remaining: 461ms
# 598:	learn: 6270.7950578	total: 687ms	remaining: 460ms
# 599:	learn: 6261.3430692	total: 688ms	remaining: 459ms
# 600:	learn: 6258.4570835	total: 689ms	remaining: 458ms
# 601:	learn: 6256.6480566	total: 690ms	remaining: 456ms
# 602:	learn: 6252.7281246	total: 691ms	remaining: 455ms
# 603:	learn: 6249.2527194	total: 692ms	remaining: 454ms
# 604:	learn: 6241.9630670	total: 693ms	remaining: 453ms
# 605:	learn: 6236.9758693	total: 694ms	remaining: 451ms
# 606:	learn: 6231.5225106	total: 695ms	remaining: 450ms
# 607:	learn: 6223.3373880	total: 696ms	remaining: 449ms
# 608:	learn: 6219.9170489	total: 697ms	remaining: 448ms
# 609:	learn: 6217.7108560	total: 698ms	remaining: 446ms
# 610:	learn: 6215.4459826	total: 699ms	remaining: 445ms
# 611:	learn: 6204.6821340	total: 700ms	remaining: 444ms
# 612:	learn: 6199.5712867	total: 701ms	remaining: 443ms
# 613:	learn: 6194.6693270	total: 702ms	remaining: 441ms
# 614:	learn: 6191.6102110	total: 703ms	remaining: 440ms
# 615:	learn: 6188.3717561	total: 704ms	remaining: 439ms
# 616:	learn: 6177.7123589	total: 705ms	remaining: 438ms
# 617:	learn: 6171.0247890	total: 706ms	remaining: 437ms
# 618:	learn: 6162.3659683	total: 707ms	remaining: 435ms
# 619:	learn: 6154.9366820	total: 708ms	remaining: 434ms
# 620:	learn: 6149.9455848	total: 709ms	remaining: 433ms
# 621:	learn: 6143.8467689	total: 710ms	remaining: 432ms
# 622:	learn: 6140.9079317	total: 711ms	remaining: 431ms
# 623:	learn: 6136.7113815	total: 712ms	remaining: 429ms
# 624:	learn: 6132.5266901	total: 713ms	remaining: 428ms
# 625:	learn: 6122.0267852	total: 714ms	remaining: 427ms
# 626:	learn: 6119.6924085	total: 715ms	remaining: 426ms
# 627:	learn: 6115.8329286	total: 716ms	remaining: 424ms
# 628:	learn: 6112.2307598	total: 717ms	remaining: 423ms
# 629:	learn: 6110.0265434	total: 718ms	remaining: 422ms
# 630:	learn: 6100.8972459	total: 719ms	remaining: 421ms
# 631:	learn: 6092.5036583	total: 720ms	remaining: 419ms
# 632:	learn: 6083.9957885	total: 721ms	remaining: 418ms
# 633:	learn: 6076.5152650	total: 722ms	remaining: 417ms
# 634:	learn: 6063.3130503	total: 723ms	remaining: 416ms
# 635:	learn: 6059.9693250	total: 724ms	remaining: 414ms
# 636:	learn: 6056.8624568	total: 725ms	remaining: 413ms
# 637:	learn: 6053.2468668	total: 726ms	remaining: 412ms
# 638:	learn: 6050.4943771	total: 727ms	remaining: 411ms
# 639:	learn: 6045.0753019	total: 728ms	remaining: 410ms
# 640:	learn: 6040.2161638	total: 729ms	remaining: 408ms
# 641:	learn: 6038.0432972	total: 730ms	remaining: 407ms
# 642:	learn: 6035.7811972	total: 731ms	remaining: 406ms
# 643:	learn: 6027.8225800	total: 732ms	remaining: 405ms
# 644:	learn: 6024.6306038	total: 733ms	remaining: 404ms
# 645:	learn: 6021.6715889	total: 734ms	remaining: 402ms
# 646:	learn: 6014.4305250	total: 735ms	remaining: 401ms
# 647:	learn: 6011.4351272	total: 736ms	remaining: 400ms
# 648:	learn: 6005.3789814	total: 737ms	remaining: 399ms
# 649:	learn: 5996.7691724	total: 738ms	remaining: 397ms
# 650:	learn: 5983.6127183	total: 739ms	remaining: 396ms
# 651:	learn: 5974.0426797	total: 740ms	remaining: 395ms
# 652:	learn: 5971.3770977	total: 741ms	remaining: 394ms
# 653:	learn: 5968.0739164	total: 742ms	remaining: 393ms
# 654:	learn: 5965.4772317	total: 743ms	remaining: 391ms
# 655:	learn: 5962.8843397	total: 744ms	remaining: 390ms
# 656:	learn: 5957.3910679	total: 745ms	remaining: 389ms
# 657:	learn: 5954.2767396	total: 746ms	remaining: 388ms
# 658:	learn: 5950.8432793	total: 747ms	remaining: 386ms
# 659:	learn: 5948.6988542	total: 748ms	remaining: 385ms
# 660:	learn: 5945.0876901	total: 749ms	remaining: 384ms
# 661:	learn: 5932.9903114	total: 750ms	remaining: 383ms
# 662:	learn: 5923.6688795	total: 751ms	remaining: 381ms
# 663:	learn: 5914.0764006	total: 751ms	remaining: 380ms
# 664:	learn: 5907.8449609	total: 753ms	remaining: 379ms
# 665:	learn: 5903.9056188	total: 754ms	remaining: 378ms
# 666:	learn: 5900.3159001	total: 755ms	remaining: 377ms
# 667:	learn: 5890.4619585	total: 756ms	remaining: 376ms
# 668:	learn: 5886.0305616	total: 757ms	remaining: 374ms
# 669:	learn: 5880.0540340	total: 758ms	remaining: 373ms
# 670:	learn: 5876.9084170	total: 759ms	remaining: 372ms
# 671:	learn: 5872.6581412	total: 759ms	remaining: 371ms
# 672:	learn: 5866.1926577	total: 760ms	remaining: 370ms
# 673:	learn: 5861.8734992	total: 761ms	remaining: 368ms
# 674:	learn: 5852.5642759	total: 762ms	remaining: 367ms
# 675:	learn: 5840.6141243	total: 763ms	remaining: 366ms
# 676:	learn: 5832.6698227	total: 764ms	remaining: 365ms
# 677:	learn: 5826.1886371	total: 765ms	remaining: 364ms
# 678:	learn: 5818.1086476	total: 766ms	remaining: 362ms
# 679:	learn: 5814.9582468	total: 767ms	remaining: 361ms
# 680:	learn: 5806.7121317	total: 768ms	remaining: 360ms
# 681:	learn: 5800.5349635	total: 769ms	remaining: 359ms
# 682:	learn: 5791.7322094	total: 770ms	remaining: 358ms
# 683:	learn: 5789.1171406	total: 771ms	remaining: 356ms
# 684:	learn: 5786.6528295	total: 772ms	remaining: 355ms
# 685:	learn: 5784.2214934	total: 773ms	remaining: 354ms
# 686:	learn: 5781.5056353	total: 774ms	remaining: 353ms
# 687:	learn: 5771.7683386	total: 775ms	remaining: 352ms
# 688:	learn: 5766.1544916	total: 776ms	remaining: 350ms
# 689:	learn: 5764.2605613	total: 777ms	remaining: 349ms
# 690:	learn: 5758.1307903	total: 778ms	remaining: 348ms
# 691:	learn: 5756.4286653	total: 783ms	remaining: 348ms
# 692:	learn: 5754.0722379	total: 785ms	remaining: 348ms
# 693:	learn: 5752.5533987	total: 786ms	remaining: 346ms
# 694:	learn: 5748.5209965	total: 787ms	remaining: 345ms
# 695:	learn: 5734.8613947	total: 788ms	remaining: 344ms
# 696:	learn: 5731.5364745	total: 789ms	remaining: 343ms
# 697:	learn: 5729.2365785	total: 790ms	remaining: 342ms
# 698:	learn: 5725.2858269	total: 791ms	remaining: 341ms
# 699:	learn: 5722.2966078	total: 792ms	remaining: 339ms
# 700:	learn: 5719.9665394	total: 793ms	remaining: 338ms
# 701:	learn: 5710.2842004	total: 796ms	remaining: 338ms
# 702:	learn: 5705.2087911	total: 798ms	remaining: 337ms
# 703:	learn: 5703.0782973	total: 799ms	remaining: 336ms
# 704:	learn: 5694.6355503	total: 800ms	remaining: 335ms
# 705:	learn: 5691.5430123	total: 801ms	remaining: 334ms
# 706:	learn: 5689.4047101	total: 802ms	remaining: 332ms
# 707:	learn: 5682.8786715	total: 803ms	remaining: 331ms
# 708:	learn: 5677.4492840	total: 804ms	remaining: 330ms
# 709:	learn: 5672.3768799	total: 806ms	remaining: 329ms
# 710:	learn: 5669.7372826	total: 808ms	remaining: 328ms
# 711:	learn: 5665.1717628	total: 809ms	remaining: 327ms
# 712:	learn: 5653.7535397	total: 810ms	remaining: 326ms
# 713:	learn: 5647.8854018	total: 811ms	remaining: 325ms
# 714:	learn: 5645.2216015	total: 812ms	remaining: 324ms
# 715:	learn: 5638.7077535	total: 813ms	remaining: 322ms
# 716:	learn: 5637.0991342	total: 814ms	remaining: 321ms
# 717:	learn: 5635.4864591	total: 815ms	remaining: 320ms
# 718:	learn: 5629.0366117	total: 816ms	remaining: 319ms
# 719:	learn: 5622.0711083	total: 817ms	remaining: 318ms
# 720:	learn: 5618.1914948	total: 818ms	remaining: 316ms
# 721:	learn: 5613.8886420	total: 819ms	remaining: 315ms
# 722:	learn: 5605.5365259	total: 820ms	remaining: 314ms
# 723:	learn: 5602.6867786	total: 821ms	remaining: 313ms
# 724:	learn: 5600.9500091	total: 822ms	remaining: 312ms
# 725:	learn: 5598.8695916	total: 823ms	remaining: 310ms
# 726:	learn: 5590.7560359	total: 824ms	remaining: 309ms
# 727:	learn: 5587.5048261	total: 825ms	remaining: 308ms
# 728:	learn: 5584.8027543	total: 826ms	remaining: 307ms
# 729:	learn: 5582.5393132	total: 826ms	remaining: 306ms
# 730:	learn: 5579.5242271	total: 827ms	remaining: 304ms
# 731:	learn: 5577.6604186	total: 828ms	remaining: 303ms
# 732:	learn: 5575.1675091	total: 829ms	remaining: 302ms
# 733:	learn: 5566.2200879	total: 830ms	remaining: 301ms
# 734:	learn: 5562.5094856	total: 831ms	remaining: 300ms
# 735:	learn: 5557.1529589	total: 834ms	remaining: 299ms
# 736:	learn: 5550.4445156	total: 835ms	remaining: 298ms
# 737:	learn: 5545.9653770	total: 836ms	remaining: 297ms
# 738:	learn: 5544.6743216	total: 837ms	remaining: 296ms
# 739:	learn: 5542.5704442	total: 838ms	remaining: 295ms
# 740:	learn: 5536.8292166	total: 839ms	remaining: 293ms
# 741:	learn: 5533.6180831	total: 840ms	remaining: 292ms
# 742:	learn: 5530.3986023	total: 842ms	remaining: 291ms
# 743:	learn: 5522.6126768	total: 843ms	remaining: 290ms
# 744:	learn: 5519.3927614	total: 844ms	remaining: 289ms
# 745:	learn: 5515.4990736	total: 845ms	remaining: 288ms
# 746:	learn: 5511.2008137	total: 846ms	remaining: 286ms
# 747:	learn: 5501.3810845	total: 847ms	remaining: 285ms
# 748:	learn: 5495.5529273	total: 848ms	remaining: 284ms
# 749:	learn: 5491.8198988	total: 849ms	remaining: 283ms
# 750:	learn: 5483.4681706	total: 850ms	remaining: 282ms
# 751:	learn: 5478.4704396	total: 851ms	remaining: 281ms
# 752:	learn: 5475.8074368	total: 852ms	remaining: 279ms
# 753:	learn: 5466.8772384	total: 853ms	remaining: 278ms
# 754:	learn: 5462.4339953	total: 854ms	remaining: 277ms
# 755:	learn: 5454.1685070	total: 855ms	remaining: 276ms
# 756:	learn: 5451.2556660	total: 856ms	remaining: 275ms
# 757:	learn: 5445.6528716	total: 857ms	remaining: 273ms
# 758:	learn: 5436.5219728	total: 858ms	remaining: 272ms
# 759:	learn: 5430.2231817	total: 859ms	remaining: 271ms
# 760:	learn: 5428.9292202	total: 859ms	remaining: 270ms
# 761:	learn: 5421.1498513	total: 860ms	remaining: 269ms
# 762:	learn: 5412.3513971	total: 861ms	remaining: 268ms
# 763:	learn: 5410.5593176	total: 863ms	remaining: 267ms
# 764:	learn: 5401.6775629	total: 864ms	remaining: 265ms
# 765:	learn: 5387.1730071	total: 865ms	remaining: 264ms
# 766:	learn: 5383.0175819	total: 866ms	remaining: 263ms
# 767:	learn: 5381.4407714	total: 867ms	remaining: 262ms
# 768:	learn: 5378.1096255	total: 868ms	remaining: 261ms
# 769:	learn: 5372.0709783	total: 869ms	remaining: 260ms
# 770:	learn: 5366.9330354	total: 872ms	remaining: 259ms
# 771:	learn: 5364.0801261	total: 873ms	remaining: 258ms
# 772:	learn: 5358.1117214	total: 874ms	remaining: 257ms
# 773:	learn: 5355.6840379	total: 875ms	remaining: 255ms
# 774:	learn: 5351.6089652	total: 876ms	remaining: 254ms
# 775:	learn: 5347.9042436	total: 877ms	remaining: 253ms
# 776:	learn: 5340.7393439	total: 878ms	remaining: 252ms
# 777:	learn: 5339.3090804	total: 879ms	remaining: 251ms
# 778:	learn: 5331.6373979	total: 880ms	remaining: 250ms
# 779:	learn: 5329.9542526	total: 881ms	remaining: 249ms
# 780:	learn: 5327.2369235	total: 882ms	remaining: 247ms
# 781:	learn: 5319.3580278	total: 883ms	remaining: 246ms
# 782:	learn: 5317.9360386	total: 884ms	remaining: 245ms
# 783:	learn: 5305.7175558	total: 885ms	remaining: 244ms
# 784:	learn: 5301.9369725	total: 886ms	remaining: 243ms
# 785:	learn: 5299.9017103	total: 887ms	remaining: 242ms
# 786:	learn: 5292.8143767	total: 888ms	remaining: 240ms
# 787:	learn: 5289.6722323	total: 889ms	remaining: 239ms
# 788:	learn: 5286.7925639	total: 890ms	remaining: 238ms
# 789:	learn: 5285.9852305	total: 891ms	remaining: 237ms
# 790:	learn: 5280.0293038	total: 892ms	remaining: 236ms
# 791:	learn: 5272.0607242	total: 893ms	remaining: 235ms
# 792:	learn: 5265.5693882	total: 894ms	remaining: 233ms
# 793:	learn: 5263.4145895	total: 895ms	remaining: 232ms
# 794:	learn: 5260.0210318	total: 896ms	remaining: 231ms
# 795:	learn: 5254.3150693	total: 897ms	remaining: 230ms
# 796:	learn: 5251.6107333	total: 898ms	remaining: 229ms
# 797:	learn: 5249.3458968	total: 899ms	remaining: 228ms
# 798:	learn: 5242.5442224	total: 900ms	remaining: 226ms
# 799:	learn: 5237.1531777	total: 901ms	remaining: 225ms
# 800:	learn: 5229.5569045	total: 902ms	remaining: 224ms
# 801:	learn: 5221.3647121	total: 903ms	remaining: 223ms
# 802:	learn: 5217.1642590	total: 904ms	remaining: 222ms
# 803:	learn: 5214.8234605	total: 905ms	remaining: 221ms
# 804:	learn: 5207.7600445	total: 906ms	remaining: 219ms
# 805:	learn: 5206.7090735	total: 907ms	remaining: 218ms
# 806:	learn: 5203.9606144	total: 908ms	remaining: 217ms
# 807:	learn: 5201.8081812	total: 909ms	remaining: 216ms
# 808:	learn: 5194.8535910	total: 910ms	remaining: 215ms
# 809:	learn: 5193.4260912	total: 911ms	remaining: 214ms
# 810:	learn: 5190.5094972	total: 912ms	remaining: 212ms
# 811:	learn: 5187.9038694	total: 912ms	remaining: 211ms
# 812:	learn: 5180.7178041	total: 913ms	remaining: 210ms
# 813:	learn: 5171.2763546	total: 914ms	remaining: 209ms
# 814:	learn: 5166.2406579	total: 915ms	remaining: 208ms
# 815:	learn: 5161.2412387	total: 916ms	remaining: 207ms
# 816:	learn: 5159.2130109	total: 917ms	remaining: 205ms
# 817:	learn: 5150.6776360	total: 918ms	remaining: 204ms
# 818:	learn: 5139.9657560	total: 919ms	remaining: 203ms
# 819:	learn: 5133.0940263	total: 920ms	remaining: 202ms
# 820:	learn: 5130.4957802	total: 921ms	remaining: 201ms
# 821:	learn: 5129.7613781	total: 923ms	remaining: 200ms
# 822:	learn: 5123.3717917	total: 924ms	remaining: 199ms
# 823:	learn: 5118.7043229	total: 925ms	remaining: 198ms
# 824:	learn: 5112.3582440	total: 926ms	remaining: 196ms
# 825:	learn: 5107.0681023	total: 927ms	remaining: 195ms
# 826:	learn: 5100.9740576	total: 929ms	remaining: 194ms
# 827:	learn: 5095.5260353	total: 930ms	remaining: 193ms
# 828:	learn: 5088.7296591	total: 931ms	remaining: 192ms
# 829:	learn: 5081.7962323	total: 932ms	remaining: 191ms
# 830:	learn: 5076.6732819	total: 933ms	remaining: 190ms
# 831:	learn: 5075.2838070	total: 934ms	remaining: 189ms
# 832:	learn: 5071.3171440	total: 935ms	remaining: 188ms
# 833:	learn: 5068.8483465	total: 936ms	remaining: 186ms
# 834:	learn: 5068.1131135	total: 937ms	remaining: 185ms
# 835:	learn: 5060.8491573	total: 938ms	remaining: 184ms
# 836:	learn: 5059.4298767	total: 939ms	remaining: 183ms
# 837:	learn: 5056.7749415	total: 940ms	remaining: 182ms
# 838:	learn: 5053.1750968	total: 941ms	remaining: 181ms
# 839:	learn: 5047.3604979	total: 942ms	remaining: 179ms
# 840:	learn: 5044.5073072	total: 943ms	remaining: 178ms
# 841:	learn: 5043.3963887	total: 944ms	remaining: 177ms
# 842:	learn: 5038.6519434	total: 945ms	remaining: 176ms
# 843:	learn: 5035.7866305	total: 946ms	remaining: 175ms
# 844:	learn: 5025.9298202	total: 947ms	remaining: 174ms
# 845:	learn: 5023.7699112	total: 948ms	remaining: 173ms
# 846:	learn: 5021.8581505	total: 949ms	remaining: 171ms
# 847:	learn: 5020.4979022	total: 950ms	remaining: 170ms
# 848:	learn: 5019.5868373	total: 951ms	remaining: 169ms
# 849:	learn: 5013.4159101	total: 952ms	remaining: 168ms
# 850:	learn: 5004.4516868	total: 953ms	remaining: 167ms
# 851:	learn: 5002.7403175	total: 954ms	remaining: 166ms
# 852:	learn: 5000.4939619	total: 955ms	remaining: 165ms
# 853:	learn: 4998.4548040	total: 956ms	remaining: 163ms
# 854:	learn: 4997.2506162	total: 957ms	remaining: 162ms
# 855:	learn: 4995.0588530	total: 958ms	remaining: 161ms
# 856:	learn: 4991.0202414	total: 959ms	remaining: 160ms
# 857:	learn: 4989.3774588	total: 961ms	remaining: 159ms
# 858:	learn: 4987.9091388	total: 963ms	remaining: 158ms
# 859:	learn: 4986.1655787	total: 964ms	remaining: 157ms
# 860:	learn: 4974.8738840	total: 967ms	remaining: 156ms
# 861:	learn: 4973.3596162	total: 968ms	remaining: 155ms
# 862:	learn: 4971.6181430	total: 969ms	remaining: 154ms
# 863:	learn: 4969.5321540	total: 970ms	remaining: 153ms
# 864:	learn: 4968.7413086	total: 971ms	remaining: 152ms
# 865:	learn: 4966.8989287	total: 972ms	remaining: 150ms
# 866:	learn: 4964.6945840	total: 973ms	remaining: 149ms
# 867:	learn: 4957.8385729	total: 974ms	remaining: 148ms
# 868:	learn: 4947.4896610	total: 975ms	remaining: 147ms
# 869:	learn: 4946.4922303	total: 976ms	remaining: 146ms
# 870:	learn: 4944.3572528	total: 977ms	remaining: 145ms
# 871:	learn: 4934.7969429	total: 978ms	remaining: 144ms
# 872:	learn: 4927.5730824	total: 979ms	remaining: 142ms
# 873:	learn: 4919.5380952	total: 980ms	remaining: 141ms
# 874:	learn: 4914.2959862	total: 981ms	remaining: 140ms
# 875:	learn: 4910.7829875	total: 982ms	remaining: 139ms
# 876:	learn: 4904.4207886	total: 983ms	remaining: 138ms
# 877:	learn: 4900.2564916	total: 984ms	remaining: 137ms
# 878:	learn: 4894.3037871	total: 985ms	remaining: 136ms
# 879:	learn: 4887.4469056	total: 986ms	remaining: 134ms
# 880:	learn: 4881.9037067	total: 987ms	remaining: 133ms
# 881:	learn: 4880.6675120	total: 988ms	remaining: 132ms
# 882:	learn: 4874.6718612	total: 989ms	remaining: 131ms
# 883:	learn: 4868.2916442	total: 990ms	remaining: 130ms
# 884:	learn: 4866.5142105	total: 991ms	remaining: 129ms
# 885:	learn: 4861.5523180	total: 992ms	remaining: 128ms
# 886:	learn: 4860.8002382	total: 993ms	remaining: 126ms
# 887:	learn: 4860.1094092	total: 994ms	remaining: 125ms
# 888:	learn: 4858.4234091	total: 995ms	remaining: 124ms
# 889:	learn: 4857.7903570	total: 996ms	remaining: 123ms
# 890:	learn: 4855.9467002	total: 996ms	remaining: 122ms
# 891:	learn: 4851.8905488	total: 997ms	remaining: 121ms
# 892:	learn: 4847.6462736	total: 998ms	remaining: 120ms
# 893:	learn: 4843.0829499	total: 1000ms	remaining: 119ms
# 894:	learn: 4839.5154433	total: 1s	remaining: 117ms
# 895:	learn: 4837.0329552	total: 1s	remaining: 116ms
# 896:	learn: 4830.4487578	total: 1s	remaining: 115ms
# 897:	learn: 4829.7183910	total: 1s	remaining: 114ms
# 898:	learn: 4827.1287846	total: 1s	remaining: 113ms
# 899:	learn: 4821.6360451	total: 1s	remaining: 112ms
# 900:	learn: 4819.2702191	total: 1.01s	remaining: 111ms
# 901:	learn: 4814.7613693	total: 1.01s	remaining: 109ms
# 902:	learn: 4812.7117077	total: 1.01s	remaining: 108ms
# 903:	learn: 4806.4607845	total: 1.01s	remaining: 107ms
# 904:	learn: 4805.5273470	total: 1.01s	remaining: 106ms
# 905:	learn: 4799.1025156	total: 1.01s	remaining: 105ms
# 906:	learn: 4792.9692127	total: 1.01s	remaining: 104ms
# 907:	learn: 4792.4250052	total: 1.01s	remaining: 103ms
# 908:	learn: 4790.2421714	total: 1.01s	remaining: 102ms
# 909:	learn: 4784.8786111	total: 1.01s	remaining: 100ms
# 910:	learn: 4782.1446145	total: 1.02s	remaining: 99.3ms
# 911:	learn: 4781.1429941	total: 1.02s	remaining: 98.2ms
# 912:	learn: 4774.7270475	total: 1.02s	remaining: 97.1ms
# 913:	learn: 4772.2882061	total: 1.02s	remaining: 96.3ms
# 914:	learn: 4771.3605210	total: 1.02s	remaining: 95.2ms
# 915:	learn: 4769.3595948	total: 1.02s	remaining: 94.1ms
# 916:	learn: 4768.0567769	total: 1.03s	remaining: 93ms
# 917:	learn: 4763.8805406	total: 1.03s	remaining: 92ms
# 918:	learn: 4761.3290922	total: 1.03s	remaining: 91ms
# 919:	learn: 4757.2074067	total: 1.03s	remaining: 90ms
# 920:	learn: 4752.8556777	total: 1.04s	remaining: 89ms
# 921:	learn: 4742.5394834	total: 1.04s	remaining: 87.9ms
# 922:	learn: 4740.3968656	total: 1.04s	remaining: 86.8ms
# 923:	learn: 4738.4354415	total: 1.04s	remaining: 85.7ms
# 924:	learn: 4737.1262251	total: 1.04s	remaining: 84.6ms
# 925:	learn: 4730.8388465	total: 1.04s	remaining: 83.4ms
# 926:	learn: 4729.1141356	total: 1.04s	remaining: 82.3ms
# 927:	learn: 4722.3855366	total: 1.05s	remaining: 81.2ms
# 928:	learn: 4721.5545472	total: 1.05s	remaining: 80.1ms
# 929:	learn: 4714.7013973	total: 1.05s	remaining: 78.9ms
# 930:	learn: 4709.1797631	total: 1.05s	remaining: 77.8ms
# 931:	learn: 4706.8165412	total: 1.05s	remaining: 76.7ms
# 932:	learn: 4704.2309923	total: 1.05s	remaining: 75.6ms
# 933:	learn: 4699.9714266	total: 1.05s	remaining: 74.5ms
# 934:	learn: 4695.1966439	total: 1.05s	remaining: 73.4ms
# 935:	learn: 4693.5301204	total: 1.06s	remaining: 72.3ms
# 936:	learn: 4686.2985413	total: 1.06s	remaining: 71.1ms
# 937:	learn: 4684.2642591	total: 1.06s	remaining: 70ms
# 938:	learn: 4678.8169131	total: 1.06s	remaining: 68.9ms
# 939:	learn: 4673.9051307	total: 1.06s	remaining: 67.7ms
# 940:	learn: 4673.3557911	total: 1.06s	remaining: 66.6ms
# 941:	learn: 4672.6539749	total: 1.06s	remaining: 65.5ms
# 942:	learn: 4668.6772413	total: 1.06s	remaining: 64.3ms
# 943:	learn: 4665.4145184	total: 1.06s	remaining: 63.2ms
# 944:	learn: 4664.1816117	total: 1.07s	remaining: 62ms
# 945:	learn: 4662.4929067	total: 1.07s	remaining: 60.9ms
# 946:	learn: 4660.6817214	total: 1.07s	remaining: 59.8ms
# 947:	learn: 4659.2495060	total: 1.07s	remaining: 58.6ms
# 948:	learn: 4658.6035614	total: 1.07s	remaining: 57.5ms
# 949:	learn: 4654.5935824	total: 1.07s	remaining: 56.4ms
# 950:	learn: 4648.7507890	total: 1.07s	remaining: 55.2ms
# 951:	learn: 4644.8239529	total: 1.07s	remaining: 54.1ms
# 952:	learn: 4641.1224952	total: 1.07s	remaining: 53ms
# 953:	learn: 4640.5130572	total: 1.07s	remaining: 51.8ms
# 954:	learn: 4634.1734720	total: 1.07s	remaining: 50.7ms
# 955:	learn: 4632.8254292	total: 1.08s	remaining: 49.6ms
# 956:	learn: 4632.3138348	total: 1.08s	remaining: 48.4ms
# 957:	learn: 4628.0929621	total: 1.08s	remaining: 47.3ms
# 958:	learn: 4623.7447037	total: 1.08s	remaining: 46.2ms
# 959:	learn: 4622.8542860	total: 1.08s	remaining: 45ms
# 960:	learn: 4621.6928726	total: 1.08s	remaining: 43.9ms
# 961:	learn: 4620.6459489	total: 1.08s	remaining: 42.8ms
# 962:	learn: 4620.1960635	total: 1.08s	remaining: 41.6ms
# 963:	learn: 4612.8734801	total: 1.08s	remaining: 40.5ms
# 964:	learn: 4611.3449713	total: 1.09s	remaining: 39.4ms
# 965:	learn: 4609.1555116	total: 1.09s	remaining: 38.3ms
# 966:	learn: 4608.0971491	total: 1.09s	remaining: 37.1ms
# 967:	learn: 4604.2814718	total: 1.09s	remaining: 36ms
# 968:	learn: 4601.5037723	total: 1.09s	remaining: 34.9ms
# 969:	learn: 4596.1113561	total: 1.09s	remaining: 33.7ms
# 970:	learn: 4588.5352411	total: 1.09s	remaining: 32.6ms
# 971:	learn: 4579.9758752	total: 1.09s	remaining: 31.5ms
# 972:	learn: 4578.2485580	total: 1.09s	remaining: 30.3ms
# 973:	learn: 4569.4077805	total: 1.09s	remaining: 29.2ms
# 974:	learn: 4561.2230207	total: 1.09s	remaining: 28.1ms
# 975:	learn: 4554.8842731	total: 1.1s	remaining: 27ms
# 976:	learn: 4553.3965550	total: 1.1s	remaining: 25.8ms
# 977:	learn: 4552.5603114	total: 1.1s	remaining: 24.7ms
# 978:	learn: 4551.5434153	total: 1.1s	remaining: 23.6ms
# 979:	learn: 4549.2481105	total: 1.1s	remaining: 22.5ms
# 980:	learn: 4548.2165019	total: 1.1s	remaining: 21.3ms
# 981:	learn: 4543.0937537	total: 1.1s	remaining: 20.2ms
# 982:	learn: 4538.9710363	total: 1.1s	remaining: 19.1ms
# 983:	learn: 4536.5298373	total: 1.1s	remaining: 18ms
# 984:	learn: 4533.7822669	total: 1.1s	remaining: 16.8ms
# 985:	learn: 4532.3696629	total: 1.11s	remaining: 15.7ms
# 986:	learn: 4528.0535941	total: 1.11s	remaining: 14.6ms
# 987:	learn: 4525.6100926	total: 1.11s	remaining: 13.5ms
# 988:	learn: 4524.0887686	total: 1.11s	remaining: 12.3ms
# 989:	learn: 4520.5565746	total: 1.11s	remaining: 11.2ms
# 990:	learn: 4519.2628801	total: 1.11s	remaining: 10.1ms
# 991:	learn: 4514.9640556	total: 1.11s	remaining: 8.97ms
# 992:	learn: 4514.0833867	total: 1.11s	remaining: 7.85ms
# 993:	learn: 4511.3589612	total: 1.11s	remaining: 6.73ms
# 994:	learn: 4510.5663030	total: 1.11s	remaining: 5.6ms
# 995:	learn: 4509.3282653	total: 1.12s	remaining: 4.48ms
# 996:	learn: 4508.1010520	total: 1.12s	remaining: 3.36ms
# 997:	learn: 4504.6429361	total: 1.12s	remaining: 2.24ms
# 998:	learn: 4503.6404009	total: 1.12s	remaining: 1.12ms
# 999:	learn: 4502.5411476	total: 1.12s	remaining: 0us
# Model Performance for CatBoost
# Mean Absolute Error: 10773.925747300507
# Mean Squared Error: 254415908.4118403
# R-squared: 0.7012584872425183
# Model Performance for LinearRegression
# Mean Absolute Error: 11454.225964778287
# Mean Squared Error: 247855600.38078812
# R-squared: 0.7089617647521111
# Model Performance for RandomForest
# Mean Absolute Error: 11837.603231707319
# Mean Squared Error: 278416887.50635666
# R-squared: 0.6730759382536797

# %%
r2_df_sorted
# Out:
#               Model        R2
# 3  LinearRegression  0.708962
# 2          CatBoost  0.701258
# 4      RandomForest  0.673076
# 1          LightGBM  0.649838
# 0           XGBoost  0.596535
